# %% [markdown]
# This file loads all the saved models adn performs evaluation on all of them, then plots the resulting figures.

# %%
from src.Preprocessing import load_data, preprocess_data
from src.train_models import train_logistic_regression, train_random_forest, train_gradient_boosting, train_decision_tree, save_model,load_model
from src.evaluate_models import evaluate_model
from src.plotting import plot_roc_curve, plot_precision_recall_curve
from src.logreg_gd import load_logreg_model, predict_logreg, calculate_logreg_metrics, plot_logreg_confusion_matrix, plot_logreg_precision_recall_curve, plot_logreg_roc_curve, generate_classification_report, grid_search_logistic_regression
import numpy as np

# %%
file_path = 'Dataset/creditcard.csv' 
data = load_data(file_path)
(X_train, y_train), (X_test, y_test), (X_train_over, y_train_over), (X_train_smote, y_train_smote), (X_train_under, y_train_under) = preprocess_data(data)

# %% [markdown]
# Firstly, we will evaluate Logistic Regression Models.

# %%
lr1 = load_model('logistic_regression_f1')
print("\nLogistic Regression with Original data and F1 scoring:")
evaluate_model(lr1, X_test, y_test)
plot_roc_curve(lr1, X_test, y_test)
plot_precision_recall_curve(lr1, X_test, y_test)
# Out:
# Logistic Regression with Original data and F1 scoring:
# Accuracy: 0.9991573329588147
# Precision: 0.8289473684210527
# Recall: 0.6428571428571429
# F1 Score: 0.7241379310344828
# ROC AUC Score: 0.8213142636063991
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.83      0.64      0.72        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.82      0.86     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# True Label: 0
# ...

# %%
lr2 = load_model('logistic_regression_precision')
print("\nLogistic Regression with Original data and precision scoring:")
evaluate_model(lr2, X_test, y_test)
plot_roc_curve(lr2, X_test, y_test)
plot_precision_recall_curve(lr2, X_test, y_test)
# Out:
# Logistic Regression with Original data and precision scoring:
# Accuracy: 0.9991046662687406
# Precision: 0.821917808219178
# Recall: 0.6122448979591837
# F1 Score: 0.7017543859649122
# ROC AUC Score: 0.8060081411574197
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.82      0.61      0.70        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.81      0.85     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# ...

# %%
lr3 = load_model('logistic_regression_recall')
print("\nLogistic Regression with Original data and recall scoring:")
evaluate_model(lr3, X_test, y_test)
plot_roc_curve(lr3, X_test, y_test)
plot_precision_recall_curve(lr1, X_test, y_test)
# Out:
# Logistic Regression with Original data and recall scoring:
# Accuracy: 0.9991573329588147
# Precision: 0.8289473684210527
# Recall: 0.6428571428571429
# F1 Score: 0.7241379310344828
# ROC AUC Score: 0.8213142636063991
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.83      0.64      0.72        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.82      0.86     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# ...

# %%
lr = load_model('logistic_regression_roc')
print("\nLogistic Regression with Original data and roc_auc scoring:")
evaluate_model(lr, X_test, y_test)
plot_roc_curve(lr, X_test, y_test)
plot_precision_recall_curve(lr, X_test, y_test)
# Out:
# Logistic Regression with Original data and roc_auc scoring:
# Accuracy: 0.9991573329588147
# Precision: 0.8289473684210527
# Recall: 0.6428571428571429
# F1 Score: 0.7241379310344828
# ROC AUC Score: 0.8213142636063991
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.83      0.64      0.72        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.82      0.86     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# ...

# %%
lr1 = load_model('logistic_regression_under_f1')
print("\nLogistic Regression with Undersampled data and F1 scoring:")
evaluate_model(lr1, X_test, y_test)
plot_roc_curve(lr1, X_test, y_test)
plot_precision_recall_curve(lr1, X_test, y_test)
# Out:
# Logistic Regression with Undersampled data and F1 scoring:
# Accuracy: 0.9718584319370809
# Precision: 0.05341246290801187
# Recall: 0.9183673469387755
# F1 Score: 0.10095344924284913
# ROC AUC Score: 0.9451589829797985
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56864
#            1       0.05      0.92      0.10        98
#
#     accuracy                           0.97     56962
#    macro avg       0.53      0.95      0.54     56962
# weighted avg       1.00      0.97      0.98     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# ...

# %%
lr1 = load_model('logistic_regression_under_precision')
print("\nLogistic Regression with Undersampled data and precision scoring:")
evaluate_model(lr1, X_test, y_test)
plot_roc_curve(lr1, X_test, y_test)
plot_precision_recall_curve(lr1, X_test, y_test)
# Out:
# Logistic Regression with Undersampled data and precision scoring:
# Accuracy: 0.9990871107053826
# Precision: 0.8194444444444444
# Recall: 0.6020408163265306
# F1 Score: 0.6941176470588235
# ROC AUC Score: 0.800906100341093
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.82      0.60      0.69        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.80      0.85     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# ...

# %%
lr1 = load_model('logistic_regression_under_recall')
print("\nLogistic Regression with Undersampled data and recall scoring:")
evaluate_model(lr1, X_test, y_test)
plot_roc_curve(lr1, X_test, y_test)
plot_precision_recall_curve(lr1, X_test, y_test)
# Out:
# Logistic Regression with Undersampled data and recall scoring:
# Accuracy: 0.9713844317264141
# Precision: 0.052570093457943924
# Recall: 0.9183673469387755
# F1 Score: 0.09944751381215469
# ROC AUC Score: 0.9449215744260562
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56864
#            1       0.05      0.92      0.10        98
#
#     accuracy                           0.97     56962
#    macro avg       0.53      0.94      0.54     56962
# weighted avg       1.00      0.97      0.98     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# ...

# %%
lr1 = load_model('logistic_regression_under_roc_auc')
print("\nLogistic Regression with Undersampled data and roc_auc scoring:")
evaluate_model(lr1, X_test, y_test)
plot_roc_curve(lr1, X_test, y_test)
plot_precision_recall_curve(lr1, X_test, y_test)
# Out:
# Logistic Regression with Undersampled data and roc_auc scoring:
# Accuracy: 0.9718584319370809
# Precision: 0.05341246290801187
# Recall: 0.9183673469387755
# F1 Score: 0.10095344924284913
# ROC AUC Score: 0.9451589829797985
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56864
#            1       0.05      0.92      0.10        98
#
#     accuracy                           0.97     56962
#    macro avg       0.53      0.95      0.54     56962
# weighted avg       1.00      0.97      0.98     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# ...

# %%
lr1 = load_model('logistic_regression_smote_f1')
print("\nLogistic Regression with SMOTE data and F1 scoring:")
evaluate_model(lr1, X_test, y_test)
plot_roc_curve(lr1, X_test, y_test)
plot_precision_recall_curve(lr1, X_test, y_test)
# Out:
# Logistic Regression with SMOTE data and F1 scoring:
# Accuracy: 0.9866226607211825
# Precision: 0.10570071258907364
# Recall: 0.9081632653061225
# F1 Score: 0.18936170212765957
# ROC AUC Score: 0.9474605718764715
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56864
#            1       0.11      0.91      0.19        98
#
#     accuracy                           0.99     56962
#    macro avg       0.55      0.95      0.59     56962
# weighted avg       1.00      0.99      0.99     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# True Label: 0
# ...

# %%
lr1 = load_model('logistic_regression_smote_precision')
print("\nLogistic Regression with SMOTE data and precision scoring:")
evaluate_model(lr1, X_test, y_test)
plot_roc_curve(lr1, X_test, y_test)
plot_precision_recall_curve(lr1, X_test, y_test)
# Out:
# Logistic Regression with SMOTE data and precision scoring:
# Accuracy: 0.9906604402935291
# Precision: 0.14309210526315788
# Recall: 0.8877551020408163
# F1 Score: 0.24645892351274787
# ROC AUC Score: 0.9392964452241223
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56864
#            1       0.14      0.89      0.25        98
#
#     accuracy                           0.99     56962
#    macro avg       0.57      0.94      0.62     56962
# weighted avg       1.00      0.99      0.99     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# ...

# %%
lr1 = load_model('logistic_regression_smote_recall')
print("\nLogistic Regression with SMOTE data and recall scoring:")
evaluate_model(lr1, X_test, y_test)
plot_roc_curve(lr1, X_test, y_test)
plot_precision_recall_curve(lr1, X_test, y_test)
# Out:
# Logistic Regression with SMOTE data and recall scoring:
# Accuracy: 0.9866226607211825
# Precision: 0.10570071258907364
# Recall: 0.9081632653061225
# F1 Score: 0.18936170212765957
# ROC AUC Score: 0.9474605718764715
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56864
#            1       0.11      0.91      0.19        98
#
#     accuracy                           0.99     56962
#    macro avg       0.55      0.95      0.59     56962
# weighted avg       1.00      0.99      0.99     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# True Label: 0
# ...

# %%
lr1 = load_model('logistic_regression_smote_roc_auc')
print("\nLogistic Regression with SMOTE data and roc_auc scoring:")
evaluate_model(lr1, X_test, y_test)
plot_roc_curve(lr1, X_test, y_test)
plot_precision_recall_curve(lr1, X_test, y_test)
# Out:
# Logistic Regression with SMOTE data and roc_auc scoring:
# Accuracy: 0.9866226607211825
# Precision: 0.10570071258907364
# Recall: 0.9081632653061225
# F1 Score: 0.18936170212765957
# ROC AUC Score: 0.9474605718764715
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56864
#            1       0.11      0.91      0.19        98
#
#     accuracy                           0.99     56962
#    macro avg       0.55      0.95      0.59     56962
# weighted avg       1.00      0.99      0.99     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# ...

# %% [markdown]
# Now, we will move onto Decision Tree Classification

# %%
dt = load_model('decision_tree_f1')
print("\nDecision Trees with original data and F1 scoring:")
evaluate_model(dt, X_test, y_test)
plot_roc_curve(dt, X_test, y_test)
plot_precision_recall_curve(dt, X_test, y_test)
# Out:
# Decision Trees with original data and F1 scoring:
# Accuracy: 0.9994908886626171
# Precision: 0.9156626506024096
# Recall: 0.7755102040816326
# F1 Score: 0.8397790055248618
# ROC AUC Score: 0.8876935516750313
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.92      0.78      0.84        98
#
#     accuracy                           1.00     56962
#    macro avg       0.96      0.89      0.92     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# True Label: 0
# ...

# %%
dt = load_model('decision_tree_precision')
print("\nDecision Trees with original data and precision scoring:")
evaluate_model(dt, X_test, y_test)
plot_roc_curve(dt, X_test, y_test)
plot_precision_recall_curve(dt, X_test, y_test)
# Out:
# Decision Trees with original data and precision scoring:
# Accuracy: 0.9994908886626171
# Precision: 0.9367088607594937
# Recall: 0.7551020408163265
# F1 Score: 0.8361581920903954
# ROC AUC Score: 0.877507055861174
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.94      0.76      0.84        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.88      0.92     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# True Label: 0
# ...

# %%
dt = load_model('decision_tree_recall')
print("\nDecision Trees with original data and recall scoring:")
evaluate_model(dt, X_test, y_test)
plot_roc_curve(dt, X_test, y_test)
plot_precision_recall_curve(dt, X_test, y_test)
# Out:
# Decision Trees with original data and recall scoring:
# Accuracy: 0.9992802219023208
# Precision: 0.7938144329896907
# Recall: 0.7857142857142857
# F1 Score: 0.7897435897435897
# ROC AUC Score: 0.8926812846691856
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.79      0.79      0.79        98
#
#     accuracy                           1.00     56962
#    macro avg       0.90      0.89      0.89     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# True Label: 0
# ...

# %%
dt = load_model('decision_tree_roc')
print("\nDecision Trees with original data and roc_auc scoring:")
evaluate_model(dt, X_test, y_test)
plot_roc_curve(dt, X_test, y_test)
plot_precision_recall_curve(dt, X_test, y_test)
# Out:
# Decision Trees with original data and roc_auc scoring:
# Accuracy: 0.9991397773954567
# Precision: 0.7333333333333333
# Recall: 0.7857142857142857
# F1 Score: 0.7586206896551724
# ROC AUC Score: 0.8926109413940027
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.73      0.79      0.76        98
#
#     accuracy                           1.00     56962
#    macro avg       0.87      0.89      0.88     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# True Label: 0
# ...

# %%
dt = load_model('decision_tree_under_f1')
print("\nDecision Trees with Undersampled data and F1 scoring:")
evaluate_model(dt, X_test, y_test)
plot_roc_curve(dt, X_test, y_test)
plot_precision_recall_curve(dt, X_test, y_test)
# Out:
# Decision Trees with Undersampled data and F1 scoring:
# Accuracy: 0.9636424282855237
# Precision: 0.03923400280242877
# Recall: 0.8571428571428571
# F1 Score: 0.07503349709691827
# ROC AUC Score: 0.9104844139400273
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     56864
#            1       0.04      0.86      0.08        98
#
#     accuracy                           0.96     56962
#    macro avg       0.52      0.91      0.53     56962
# weighted avg       1.00      0.96      0.98     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# True Label: 0
# ...

# %%
dt = load_model('decision_tree_under_precision')
print("\nDecision Trees with Undersampled data and precision scoring:")
evaluate_model(dt, X_test, y_test)
plot_roc_curve(dt, X_test, y_test)
plot_precision_recall_curve(dt, X_test, y_test)
# Out:
# Decision Trees with Undersampled data and precision scoring:
# Accuracy: 0.9459990871107054
# Precision: 0.028200253485424587
# Recall: 0.9081632653061225
# F1 Score: 0.054701905347264906
# ROC AUC Score: 0.9271137795298199
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97     56864
#            1       0.03      0.91      0.05        98
#
#     accuracy                           0.95     56962
#    macro avg       0.51      0.93      0.51     56962
# weighted avg       1.00      0.95      0.97     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# ...

# %%
dt = load_model('decision_tree_under_recall')
print("\nDecision Trees with Undersampled data and recall scoring:")
evaluate_model(dt, X_test, y_test)
plot_roc_curve(dt, X_test, y_test)
plot_precision_recall_curve(dt, X_test, y_test)
# Out:
# Decision Trees with Undersampled data and recall scoring:
# Accuracy: 0.9363259717004319
# Precision: 0.02349446394815015
# Recall: 0.8877551020408163
# F1 Score: 0.04577742699289661
# ROC AUC Score: 0.9120823906377409
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97     56864
#            1       0.02      0.89      0.05        98
#
#     accuracy                           0.94     56962
#    macro avg       0.51      0.91      0.51     56962
# weighted avg       1.00      0.94      0.97     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# ...

# %%
dt = load_model('decision_tree_under_roc')
print("\nDecision Trees with Undersampled data and roc_auc scoring:")
evaluate_model(dt, X_test, y_test)
plot_roc_curve(dt, X_test, y_test)
plot_precision_recall_curve(dt, X_test, y_test)
# Out:
# Decision Trees with Undersampled data and roc_auc scoring:
# Accuracy: 0.9481759769671009
# Precision: 0.028731836195508585
# Recall: 0.8877551020408163
# F1 Score: 0.05566218809980806
# ROC AUC Score: 0.9180176044812973
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97     56864
#            1       0.03      0.89      0.06        98
#
#     accuracy                           0.95     56962
#    macro avg       0.51      0.92      0.51     56962
# weighted avg       1.00      0.95      0.97     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# ...

# %%
dt = load_model('decision_tree_smote_f1')
print("\nDecision Trees with SMOTE data and F1 scoring:")
evaluate_model(dt, X_test, y_test)
plot_roc_curve(dt, X_test, y_test)
plot_precision_recall_curve(dt, X_test, y_test)
# Out:
# Decision Trees with SMOTE data and F1 scoring:
# Accuracy: 0.9972086654260736
# Precision: 0.35944700460829493
# Recall: 0.7959183673469388
# F1 Score: 0.49523809523809526
# ROC AUC Score: 0.8967369692671666
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.36      0.80      0.50        98
#
#     accuracy                           1.00     56962
#    macro avg       0.68      0.90      0.75     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# True Label: 0
# ...

# %%
dt = load_model('decision_tree_smote_precision')
print("\nDecision Trees with SMOTE data and precision scoring:")
evaluate_model(dt, X_test, y_test)
plot_roc_curve(dt, X_test, y_test)
plot_precision_recall_curve(dt, X_test, y_test)
# Out:
# Decision Trees with SMOTE data and precision scoring:
# Accuracy: 0.9974193321863699
# Precision: 0.3804878048780488
# Recall: 0.7959183673469388
# F1 Score: 0.5148514851485149
# ROC AUC Score: 0.896842484179941
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.38      0.80      0.51        98
#
#     accuracy                           1.00     56962
#    macro avg       0.69      0.90      0.76     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# True Label: 0
# ...

# %%
dt = load_model('decision_tree_smote_recall')
print("\nDecision Trees with SMOTE data and recall scoring:")
evaluate_model(dt, X_test, y_test)
plot_roc_curve(dt, X_test, y_test)
plot_precision_recall_curve(dt, X_test, y_test)
# Out:
# Decision Trees with SMOTE data and recall scoring:
# Accuracy: 0.9971384431726414
# Precision: 0.3515981735159817
# Recall: 0.7857142857142857
# F1 Score: 0.48580441640378547
# ROC AUC Score: 0.8916085497226465
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.35      0.79      0.49        98
#
#     accuracy                           1.00     56962
#    macro avg       0.68      0.89      0.74     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# True Label: 0
# ...

# %% [markdown]
# By looking at the above 2 classifiers, we have seen a pattern that f1 scoring provides the most decent results as we want the trade off between precision and recall.<br>
# So, for the next models we will only use the f1 scoring models. We can also use other models we intend to see how they will perform.<br>
#
# Let's see Random Forest Models.

# %%
rf = load_model('random_forest')
print("\nRandom Forest with original data:")
evaluate_model(rf, X_test, y_test)
plot_roc_curve(rf, X_test, y_test)
plot_precision_recall_curve(rf, X_test, y_test)
# Out:
# Random Forest with original data:
# Accuracy: 0.9996137776061234
# Precision: 0.9418604651162791
# Recall: 0.826530612244898
# F1 Score: 0.8804347826086957
# ROC AUC Score: 0.9132213415754596
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.94      0.83      0.88        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.91      0.94     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# True Label: 0
# Predicted Label: 0

# %%
rf = load_model('random_forest_under')
print("\nRandom Forest with Undersampled data:")
evaluate_model(rf, X_test, y_test)
plot_roc_curve(rf, X_test, y_test)
plot_precision_recall_curve(rf, X_test, y_test)
# Out:
# Random Forest with Undersampled data:
# Accuracy: 0.9805835469260209
# Precision: 0.07432432432432433
# Recall: 0.8979591836734694
# F1 Score: 0.1372854914196568
# ROC AUC Score: 0.9393425631366785
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56864
#            1       0.07      0.90      0.14        98
#
#     accuracy                           0.98     56962
#    macro avg       0.54      0.94      0.56     56962
# weighted avg       1.00      0.98      0.99     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# True Label: 0
# ...

# %%
#Use this to evaluate the Random Forest model with SMOTE data 
"""rf = load_model('random_forest_smote')
print("\nRandom Forest with SMOTE data:")
evaluate_model(rf, X_test, y_test)
plot_roc_curve(rf, X_test, y_test)
plot_precision_recall_curve(rf, X_test, y_test)"""
# Out:
# 'rf = load_model(\'random_forest_smote\')\nprint("\nRandom Forest with SMOTE data:")\nevaluate_model(rf, X_test, y_test)\nplot_roc_curve(rf, X_test, y_test)\nplot_precision_recall_curve(rf, X_test, y_test)'

# %% [markdown]
# Now let's take a look at GradientBoosting Classifier

# %%
#Use this to evaluate Gradient Boosting model with original data
"""gb = load_model('gradient_boosting')
print("\nGradient Boosting with original data:")
evaluate_model(gb, X_test, y_test)
plot_roc_curve(gb, X_test, y_test)
plot_precision_recall_curve(gb, X_test, y_test)"""
# Out:
# 'gb = load_model(\'gradient_boosting\')\nprint("\nGradient Boosting with original data:")\nevaluate_model(gb, X_test, y_test)\nplot_roc_curve(gb, X_test, y_test)\nplot_precision_recall_curve(gb, X_test, y_test)'

# %%
gb = load_model('gradient_boosting_under')
print("\nGradient Boosting with Undersampled data:")
evaluate_model(gb, X_test, y_test)
plot_roc_curve(gb, X_test, y_test)
plot_precision_recall_curve(gb, X_test, y_test)
# Out:
# Gradient Boosting with Undersampled data:
# Accuracy: 0.9708577648256732
# Precision: 0.05063291139240506
# Recall: 0.8979591836734694
# F1 Score: 0.09586056644880174
# ROC AUC Score: 0.9344712913302632
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56864
#            1       0.05      0.90      0.10        98
#
#     accuracy                           0.97     56962
#    macro avg       0.53      0.93      0.54     56962
# weighted avg       1.00      0.97      0.98     56962
#
#
# Specific Example 100:
# Features: [-2.87127263 -1.59133085 -0.0035864   1.8265693  -0.54091559  0.60914837
#   0.0306744   0.36591119  0.61817212  0.72390182  0.6382805   0.70670728
#  -0.33876862 -0.03850152  0.40464308 -0.68115838  0.7873919   0.22141528
#   2.54322582 -1.72409928 -0.62259398  0.44091004 -1.85651358 -0.1535926
#   0.40245083 -0.21102547 -2.31823186 -2.11568387  0.30393603]
# True Label: 0
# ...

# %%
#Use this to evaluate Gradient Boosting model with SMOTE data
"""gb = load_model('gradient_boosting_smote')
print("\nGradient Boosting with SMOTE data:")
evaluate_model(gb, X_test, y_test)
plot_roc_curve(gb, X_test, y_test)
plot_precision_recall_curve(gb, X_test, y_test)"""
# Out:
# 'gb = load_model(\'gradient_boosting_smote\')\nprint("\nGradient Boosting with SMOTE data:")\nevaluate_model(gb, X_test, y_test)\nplot_roc_curve(gb, X_test, y_test)\nplot_precision_recall_curve(gb, X_test, y_test)'

# %% [markdown]
# Now, finally we will evaluate the Logistic Regression Gradient Descent function we have built from scratch.

# %%
# Load the best model
best_model = load_logreg_model('models/logistic_regression_gradient_descent.npy')

# Make predictions on the test set using the best model
y_pred = predict_logreg(X_test, best_model)

# Evaluate the model and print metrics
precision, recall, f1, roc_auc = calculate_logreg_metrics(y_test, y_pred)
print("Logistic Regression Gradient Descent with original data:")
print("Final Model Metrics:")
print(f"Precision: {precision:.2f}, Recall: {recall:.2f}, F1 Score: {f1:.2f}, ROC AUC: {roc_auc:.2f}")

# Plot ROC curve, precision-recall curve, and confusion matrix
plot_logreg_roc_curve(y_test, y_pred)
plot_logreg_precision_recall_curve(y_test, y_pred)
plot_logreg_confusion_matrix(y_test, y_pred)

# Generate and print the classification report
generate_classification_report(y_test, y_pred)
# Out:
# Logistic Regression Gradient Descent with original data:
# Final Model Metrics:
# Precision: 0.83, Recall: 0.60, F1 Score: 0.70, ROC AUC: 0.80
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.83      0.60      0.70        98
#
#     accuracy                           1.00     56962
#    macro avg       0.92      0.80      0.85     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
# Load the best model
best_model = load_logreg_model('models/logistic_regression_gradient_descent_undersampled.npy')

# Make predictions on the test set using the best model
y_pred = predict_logreg(X_test, best_model)

# Evaluate the model and print metrics
precision, recall, f1, roc_auc = calculate_logreg_metrics(y_test, y_pred)
print("Logistic Regression Gradient Descent with Undersampled data:")
print("Final Model Metrics:")
print(f"Precision: {precision:.2f}, Recall: {recall:.2f}, F1 Score: {f1:.2f}, ROC AUC: {roc_auc:.2f}")

# Plot ROC curve, precision-recall curve, and confusion matrix
plot_logreg_roc_curve(y_test, y_pred)
plot_logreg_precision_recall_curve(y_test, y_pred)
plot_logreg_confusion_matrix(y_test, y_pred)

# Generate and print the classification report
generate_classification_report(y_test, y_pred)
# Out:
# Logistic Regression Gradient Descent with Undersampled data:
# Final Model Metrics:
# Precision: 0.05, Recall: 0.92, F1 Score: 0.10, ROC AUC: 0.95
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56864
#            1       0.05      0.92      0.10        98
#
#     accuracy                           0.97     56962
#    macro avg       0.53      0.95      0.54     56962
# weighted avg       1.00      0.97      0.98     56962

# %%
# Load the best model
best_model = load_logreg_model('models/logistic_regression_gradient_descent_smote.npy')

# Make predictions on the test set using the best model
y_pred = predict_logreg(X_test, best_model)

# Evaluate the model and print metrics
precision, recall, f1, roc_auc = calculate_logreg_metrics(y_test, y_pred)
print("Logistic Regression Gradient Descent with SMOTE data:")
print("Final Model Metrics:")
print(f"Precision: {precision:.2f}, Recall: {recall:.2f}, F1 Score: {f1:.2f}, ROC AUC: {roc_auc:.2f}")

# Plot ROC curve, precision-recall curve, and confusion matrix
plot_logreg_roc_curve(y_test, y_pred)
plot_logreg_precision_recall_curve(y_test, y_pred)
plot_logreg_confusion_matrix(y_test, y_pred)

# Generate and print the classification report
generate_classification_report(y_test, y_pred)
# Out:
# Logistic Regression Gradient Descent with SMOTE data:
# Final Model Metrics:
# Precision: 0.05, Recall: 0.92, F1 Score: 0.10, ROC AUC: 0.95
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56864
#            1       0.05      0.92      0.10        98
#
#     accuracy                           0.97     56962
#    macro avg       0.53      0.95      0.54     56962
# weighted avg       1.00      0.97      0.98     56962

# %%
print(X_test)
print(y_test)
# Out:
# [[-0.34434507  0.8527222  -0.73247838 ...  1.32258469  0.88256448
#   -0.26127341]
#  [-1.44474752 -1.67452292  1.67372731 ...  0.27451198 -1.55093908
#   -0.30585207]
#  [-1.82596047  1.40399293  0.86198405 ...  1.36860161  1.54435108
#   -0.04909498]
#  ...
#  [-0.53491142  0.41490872  0.12890793 ...  0.04297833  0.43968751
#   -0.28770076]
#  [ 1.10276226 -0.65659184 -0.56640925 ... -0.00635543 -0.17197637
#   -0.27346757]
#  [ 0.62697885 -0.36532556  0.16271869 ...  0.06142974  0.15200374
#   -0.11374403]]
# 263020    0
# 11378     0
# 147283    0
# 219439    0
# 36939     0
#          ..
# 54199     0
# 184616    0
# 274532    0
# 269819    0
# 64170     0
# Name: Class, Length: 56962, dtype: int64

# %%
sample = 30
pred = gb.predict(X_test[sample].reshape(1,-1))
print("True Label:", y_test.iloc[sample])
print("Predicted Label:", pred)
# Out:
# True Label: 0
# Predicted Label: [1]

# %%
a = np.array([-0.34434507, 0.8527222, -0.73247838, -0.93820015, 1.0063407, -0.98211346,
              1.52444586, -0.51428187, 0.28367345, 0.59765651, -0.84037937, -0.23014565,
              -0.20076613, 0.27787713, -0.05085047, -0.84610208, -0.71304754, -0.4683608,
              -0.19980406, 0.51149269, 0.10902895, 1.11620956, -0.35923441, 1.16883333,
              -0.26058503, 0.09352914, 1.32258469, 0.88256448, -0.26127341])

# %%
pred = gb.predict(a.reshape(1,-1))
print(pred)
# Out:
# [0]
